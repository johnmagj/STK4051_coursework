# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../../Datasets_from_the_book/trivariatenormal.dat", sep="\s+", dtype=np.float64)
categories = df.columns.tolist()
data = df.to_numpy()

# %%
data[16]
# Out:
# array([-0.11,   nan,  7.17])

# %%
plt.plot(data[16])
